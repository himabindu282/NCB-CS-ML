# %%
a="welcome to ncb"
a.upper()
# Out:
# 'WELCOME TO NCB'

# %%
a="welcome to ncb"
a.upper()
# Out:
# 'WELCOME TO NCB'

# %%
a.replace("to","To")
# Out:
# 'welcome To ncb'

# %%
#And,or,not
x=20
x<20 and x>30
# Out:
# False

# %%
x=20
x==20 and x==10
# Out:
# False

# %%
f=True
b=False
if f==True and b==True:
    print("COVID positive")
else:
    print("COVID negative")
# Out:
# COVID negative

# %%
salary=int(input("enter salary"))
land=int(input("enter land"))


if salary >=50000 or land>=5:
      print("loan approve")
else:
      print("not eligible")
# Out:
# enter salary30000
# enter land6
# loan approve

# %%
s="Hello"
for i in s:
   print(i)
# Out:
# H
# e
# l
# l
# o

# %%
for i in range(2,11,2):
   print(i)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
n=int(input())
sum=0
i=1


while i<=n:
    sum=sum+i
    i=i+1
print("sum of 0 to {} is {}". format (n,sum))
# Out:
# 10
# sum of 0 to 10 is 55

# %%
inp_p=input("enter a password ")
sec_p="hima"
count=0


while(count<3) and (inp_p != sec_p):
    count=count+1
    inp_p=input("try again ")



if inp_p==sec_p:
     print("correct password")
else:
     print("wrong password system locked")
# Out:
# enter a password hima
# correct password

# %%
li=["a","b","c","d"]
li[1:3]
# Out:
# ['b', 'c']

# %%
li=["a","b","c","d"]
li.append("e")
li
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
li.insert(1,"s")
li
# Out:
# ['a', 's', 'b', 'c', 'd', 'e']

# %%
li=["v","o","k"]
li.extend(li)
li
# Out:
# ['v', 'o', 'k', 'v', 'o', 'k']

# %%
li.remove("k")
li
# Out:
# ['v', 'o', 'v', 'o', 'k']

# %%
li.clear()
li
# Out:
# []

# %%
list=8
list
# Out:
# 8

# %%
list=[2,3,4,5,6,7,8]
result=[]


for i in list:
    result.append(i*2)
print(result)
# Out:
# [4, 6, 8, 10, 12, 14, 16]

# %%
list1=[2,3,4,5,6,7,8]
result1=[x**2 for x in list1]
result1
# Out:
# [4, 9, 16, 25, 36, 49, 64]

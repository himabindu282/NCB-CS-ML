# %%
print("welcome to ncb")
# Out:
# welcome to ncb

# %%
a=20
print(a)
# Out:
# 20

# %%
a
# Out:
# 20

# %%
a=20
b=30
c=a+b
print("sum of{}and{}is{}".format(a,b,c))
# Out:
# sum of20and30is50

# %%
a=20
b=30
c=a+b
print("sum of{1} and {0} is{2}". format (a,b,c))
# Out:
# sum of30 and 20 is50

# %%
a=34
type(a)
# Out:
# int

# %%
b=100.0
type(b)
# Out:
# float

# %%
b
# Out:
# 100.0

# %%
a="ncb"
type(a)
# Out:
# str

# %%
a=True
type(a)
# Out:
# bool

# %%
d=True+99
d
# Out:
# 100

# %%
e=False*100
e
# Out:
# 0

# %%
a=100.0
b=1000
a+b
# Out:
# 1100.0

# %%
a=100
b=str(a)

# %%
float(a)
# Out:
# 100.0

# %%
a="50"
type(a)
# Out:
# str

# %%
int(a)
# Out:
# 50

# %%
20==30
# Out:
# False

# %%
s=int(input())
if s==1:
   print("on")
else:
   print("off")
# Out:
# 1
# on

# %%
t=int(input())
if t==1:
  print("value is 1")
elif t==2:
   print("value is 2")
else:
   print("other")
# Out:
# 2
# value is 2

# %%
bill_amount=5000
friend=int(input())

if friend>0:
    print("Amount from friend",friend)
    if friend>=bill_amount:
       print("full bill paid")
    else:
       balance=bill_amount-friend
       print("balance amount is",balance)

else:
    print("full bill pending")
# Out:
# 4500
# Amount from friend 4500
# balance amount is 500

# %%
s="welcome to NCB"
len(s)
s[0:7]
# Out:
# 'welcome'

# %%
n=input()
a=n[0:2]
if a=="KA":
  print("gate open")
elif a=="TN":
   print("gate open")
elif a=="AP":
   print("gate open")
else:
   print("closed")
# Out:
# TN
# gate open
